# %%
import osmnx as ox
import pandas as pd
import sys
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = ox.graph_from_bbox(34.874208,34.892444, 135.184558, 135.234511, network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
new_G = G.copy()
for u, v, data in G.edges(data=True):
    # print(data['highway'])
    if data['highway'] == 'primary' or data['highway'] == 'primary_link' or data['highway'] == 'trunk' or data['highway'] == 'trunk_link':
        new_G.remove_edge(u, v)
cG = max(nx.strongly_connected_components(new_G), key=len)

new_G = new_G.subgraph(cG)
ox.plot_graph(new_G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
imp=[]
check=[]
nodes = []
#sanda
imp.append(ox.nearest_nodes(new_G, 135.23009310634404, 34.8886011601961))
#library
imp.append(ox.nearest_nodes(new_G, 135.2187971439878, 34.87827106118329))
#museum
imp.append(ox.nearest_nodes(new_G, 135.19888126989827, 34.88623668338764))
#hotel
imp.append(ox.nearest_nodes(new_G, 135.20264577735248, 34.886821196454584))
#culturalcenter
imp.append(ox.nearest_nodes(new_G, 135.22151651613189, 34.890988087519))
#castle
imp.append(ox.nearest_nodes(new_G, 135.22110990752168, 34.886846934638804))
#yokoyamamall
imp.append(ox.nearest_nodes(new_G, 135.2245846719593, 34.87903453349356))
#vet
imp.append(ox.nearest_nodes(new_G, 135.21328907844475, 34.8910322830982))
#aeon
imp.append(ox.nearest_nodes(new_G, 135.20181477075107, 34.88498567019433))


#fujigaoka6
nodes.append(ox.nearest_nodes(new_G, 135.20035522657895, 34.88920026565635))
#fujigaoka1
nodes.append(ox.nearest_nodes(new_G, 135.19563897128566, 34.88813876056455))
#fujigaoka2
nodes.append(ox.nearest_nodes(new_G, 135.19209784430188, 34.88869020591812))
#fujigaoka4
nodes.append(ox.nearest_nodes(new_G, 135.19139162128582, 34.89079342826983))
#fujigaoka4
nodes.append(ox.nearest_nodes(new_G, 135.18803776085718, 34.889872416278905))
#fujigaoka3
nodes.append(ox.nearest_nodes(new_G, 135.1873933010291, 34.887627665486896))
#fujigaoka3
nodes.append(ox.nearest_nodes(new_G, 135.18502094168713, 34.889443390122366))
#fujigaoka5
nodes.append(ox.nearest_nodes(new_G, 135.20143372444412, 34.892029163229836)) 

#yayoigaokapark
nodes.append(ox.nearest_nodes(new_G, 135.18921460053437, 34.88457838356989))
#yayoigaoka4
nodes.append(ox.nearest_nodes(new_G, 135.19037230121342, 34.88393737690503))
#yayoigaoka3
nodes.append(ox.nearest_nodes(new_G, 135.19218316634312, 34.882028508731935))
#yayoigaoka3park
nodes.append(ox.nearest_nodes(new_G, 135.19362322239004, 34.883027205708615))
#yayoigaoka5
nodes.append(ox.nearest_nodes(new_G, 135.1944237569192, 34.88428237053674))
#yayoigaoka2
nodes.append(ox.nearest_nodes(new_G, 135.19578516487238, 34.88143003646518))
#yayoigaoka1
nodes.append(ox.nearest_nodes(new_G, 135.20046293740268, 34.884756846918144))
#apartments
34.8831803131699, 135.20009967247245



#mukogaoka5
nodes.append(ox.nearest_nodes(new_G, 135.20511119932326, 34.88463210840359))
#mukogaoka4
nodes.append(ox.nearest_nodes(new_G, 135.20743644602376, 34.883567739141085))
#mukogaoka6
nodes.append(ox.nearest_nodes(new_G, 135.20827792195482, 34.88653358594781))
#mukogaoka8
nodes.append(ox.nearest_nodes(new_G, 135.20759524132086, 34.889551607295715))
#mukogaoka3
nodes.append(ox.nearest_nodes(new_G, 135.21549880202562, 34.887413619427164))
#mukogaoka2
nodes.append(ox.nearest_nodes(new_G, 135.2120612160504, 34.882567435569044))
#mukogaoka1
nodes.append(ox.nearest_nodes(new_G, 135.21529303409957, 34.88046775226452))


#shimofukatapark
nodes.append(ox.nearest_nodes(new_G, 135.20992260153608, 34.88731257883604))
#shimofukataparkeast
nodes.append(ox.nearest_nodes(new_G, 135.21295283096387, 34.88744418491797))
#tenjinpark
nodes.append(ox.nearest_nodes(new_G, 135.21394199251438, 34.88855674080821))
#tenjinkaminomiyapark
nodes.append(ox.nearest_nodes(new_G, 135.21633439782585, 34.88888546185469))
#kitatanipark
nodes.append(ox.nearest_nodes(new_G, 135.21686241564075, 34.885781622328246))


#hasamagaoka4
nodes.append(ox.nearest_nodes(new_G, 135.2014644303538, 34.879893140692936))
#hasamagaoka3
nodes.append(ox.nearest_nodes(new_G, 135.2015613276993, 34.877667390869156))
#hasamagaoka2
nodes.append(ox.nearest_nodes(new_G, 135.20631697248425, 34.88091688221223))
#hasamagaoka5
nodes.append(ox.nearest_nodes(new_G, 135.2026518527973, 34.882494381815064))
#neighborhood
nodes.append(ox.nearest_nodes(new_G, 135.20485481477454, 34.87901267964365))
#neighborhood2
nodes.append(ox.nearest_nodes(new_G, 135.2086344139608, 34.88096386461507))

#nishiyama2
nodes.append(ox.nearest_nodes(new_G, 135.21611678357968, 34.88387280552645))

#minamigaoka1
nodes.append(ox.nearest_nodes(new_G, 135.2202966315175, 34.88089073311706))

#tenjin2
nodes.append(ox.nearest_nodes(new_G, 135.2194588590709, 34.889617359209105))
#tenjin3
nodes.append(ox.nearest_nodes(new_G, 135.2156156618071, 34.887476948180975))


#aioicho
nodes.append(ox.nearest_nodes(new_G, 135.22847605614822, 34.88251745696772))
#sandacho
nodes.append(ox.nearest_nodes(new_G, 135.22503836408669, 34.883986487321366))

#neighborhood
nodes.append(ox.nearest_nodes(new_G, 135.22229908675666, 34.88424801017238))
#neighborhood
nodes.append(ox.nearest_nodes(new_G, 135.21956754321926, 34.88253345722793))



#yokoyamapark
nodes.append(ox.nearest_nodes(new_G, 135.2223691673148, 34.87536861843868))
#neighborhood
nodes.append(ox.nearest_nodes(new_G, 135.22204214489443, 34.877748795394254))
#tainakacho
nodes.append(ox.nearest_nodes(new_G, 135.22714962677364, 34.87969747419635))

#ekimaecho
nodes.append(ox.nearest_nodes(new_G, 135.23322643492787, 34.886804993154534))
#chuocho
nodes.append(ox.nearest_nodes(new_G, 135.2263392117847, 34.88795770648777))
#nakamachi
nodes.append(ox.nearest_nodes(new_G, 135.23031849626366, 34.88528703906928))
#takasugi1
nodes.append(ox.nearest_nodes(new_G, 135.2320266089693, 34.88930079630959))
#miwa1
nodes.append(ox.nearest_nodes(new_G, 135.228395870037, 34.89131347415299))
#miwa2
nodes.append(ox.nearest_nodes(new_G, 135.22384723340662, 34.89245261765007))
#miwa4
nodes.append(ox.nearest_nodes(new_G, 135.22365521885797, 34.89676615124622))


nc = ['r' if node in nodes else 'g' if node in imp else 'g' if node in check else '#336699' for node in new_G.nodes()]
size = [30 if node in nodes else 30 if node in imp else 5 for node in new_G.nodes()]


print(len(nodes)+len(imp))

ox.plot_graph(new_G, node_color=nc, node_size=size, bgcolor="white", filepath='sanda_south.png', save=False)
# Out:
# 60
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
for i in range(len(imp)):
    nodes.append(imp[i])

# %%
distance_matrix = np.zeros((len(nodes), len(nodes)))

for i in range(len(nodes)):
    for j in range(len(nodes)):
        try:
            distance_matrix[i][j] = nx.shortest_path_length(new_G, nodes[i], nodes[j], weight='length')
        except:
            distance_matrix[i][j] = 1000000000

# %%
len(distance_matrix)
# Out:
# 60

# %%
show=[nodes[15], nodes[10]]
nc = ['r' if node in show else '#336699' for node in new_G.nodes()]
size = [30 if node in show else 5 for node in new_G.nodes()]

ox.plot_graph(new_G, node_color=nc, node_size=size, bgcolor="white")
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
import random
i=random.randint(0, 59)
j=random.randint(0, 59)
if i==j:
    j=random.randint(0, 59)

print(i, j)

route = nx.shortest_path(new_G, nodes[i], nodes[j], weight='length')
show=[nodes[i], nodes[j]]
nc = ['r' if node in show else '#336699' for node in new_G.nodes()]
size = [30 if node in show else 5 for node in new_G.nodes()]
fig, ax = ox.plot_graph_route(new_G, node_color=nc, node_size=size, bgcolor="white", route=route, route_color='r', route_linewidth=4, show=True)
# Out:
# 51 33

# %%
patrol= np.empty([len(nodes), len(nodes), len(nodes)])
count=0
for i in range(len(nodes)):
    for j in range(len(nodes)):
        route = nx.shortest_path(new_G, nodes[i], nodes[j], weight='length')
        count=0
        for m in route[1:-1]:
            for n in range(len(nodes)):
                if(m==nodes[n]):
                    patrol[i][j][count]=n
                    count+=1
        patrol[i][j][count]=1000

for i in range(len(nodes)):
    for j in range(len(nodes)):
        for m in range(len(nodes)):
            print(patrol[i][j][m])
            if(patrol[i][j][m]==1000):
                break
            
   

# for i in range(len(nodes)):
#     for j in range(len(nodes)):
#         for m in range(len(nodes)):
#             print(patrol[i][j][m])
# Out:
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 4.0
# 1000.0
# 4.0
# 5.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 7.0
# 15.0
# 14.0
# 1000.0
# 7.0
# 15.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 24.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 24.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 16.0
# 1000.0
# 7.0
# 21.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 24.0
# 1000.0
# 7.0
# 24.0
# 43.0
# 1000.0
# 7.0
# 27.0
# 1000.0
# 7.0
# 1000.0
# 7.0
# 24.0
# 1000.0
# 7.0
# 27.0
# 1000.0
# 7.0
# 27.0
# 1000.0
# 7.0
# 37.0
# 1000.0
# 7.0
# 37.0
# 1000.0
# 7.0
# 37.0
# 1000.0
# 7.0
# 27.0
# 1000.0
# 7.0
# 42.0
# 57.0
# 1000.0
# 7.0
# 24.0
# 43.0
# 1000.0
# 7.0
# 24.0
# 43.0
# 1000.0
# 7.0
# 42.0
# 1000.0
# 7.0
# 42.0
# ...

# %%
for m in range(len(nodes)):
            print(patrol[1][41][m])
            if(patrol[1][41][m]==1000):
                break
# Out:
# 22.0
# 37.0
# 1000.0

# %%
i=random.randint(0, 59)
j=random.randint(0, 59)
if i==j:
    j=random.randint(0, 59)

print(i, j)
route = nx.shortest_path(new_G, nodes[i], nodes[j], weight='length')
show=[nodes[i], nodes[j]]
nc = ['r' if node in show else '#336699' for node in new_G.nodes()]
size = [30 if node in show else 5 for node in new_G.nodes()]
fig, ax = ox.plot_graph_route(new_G, node_color=nc, node_size=size, bgcolor="white", route=route, route_color='r', route_linewidth=4, show=True)
# Out:
# 56 3

# %%
i=random.randint(0, 59)
j=random.randint(0, 59)
if i==j:
    j=random.randint(0, 59)

print('i=', i, 'j=', j)
print(len(nodes))
print(nodes[i], nodes[j])
route = nx.shortest_path(new_G, nodes[i], nodes[j], weight='length')
show=[nodes[i], nodes[j]]
nc = ['r' if node in show else '#336699' for node in new_G.nodes()]
size = [30 if node in show else 5 for node in new_G.nodes()]
fig, ax = ox.plot_graph_route(new_G, node_color=nc, node_size=size, bgcolor="white", route=route, route_color='r', route_linewidth=4, show=True)

check=[]
check.append(nodes[i])
for m in range(len(nodes)):
            if(patrol[i][j][m]==1000):
                break
            print(patrol[i][j][m])
            num=int(patrol[i][j][m])
            check.append(nodes[num])
check.append(nodes[j])

print(check)

nc = ['g' if node in check else 'r' if node in nodes else 'r' if node in imp else '#336699' for node in new_G.nodes()]
size = [30 if node in check else 10 if node in nodes else 5 for node in new_G.nodes()]


ox.plot_graph(new_G, node_color=nc, node_size=size, bgcolor="white")
# Out:
# i= 46 j= 47
# 60
# 5403999044 4255429664
# 48.0
# [5403999044, 4255429697, 4255429664]
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
#specify path for export
path = r'/Users/satokamimura/Desktop/seniorproject/sanda/sanda_south_dist.txt'

#export DataFrame to text file
with open(path, 'w') as f:
    f.write(str(len(nodes)))
    f.write('\n')
    for i in range(0, len(distance_matrix)):
        for j in range(0, len(distance_matrix[i])):
            f.write( "{:.2f}".format(distance_matrix[i][j])) 
            f.write(' ') 
        f.write('\n')
    f.write('\n')
    f.write('\n')
    
    for i in range(len(nodes)):
        for j in range(len(nodes)):
            for m in range(len(nodes)):
                f.write("{:.0f}".format(patrol[i][j][m]))
                f.write(' ') 
                if(patrol[i][j][m]==1000):
                    f.write('\n')
                    break

# %%
rand=[]

for i in range(0, 5, 1):
    rand.append(random.randint(0,59))

if(len(np.unique(rand))!=len(rand)):
    for i in range(0, 5):
        rand[i]=random.randint(0,49)
        
print(np.unique(rand))
    
route1 = nx.shortest_path(new_G, nodes[rand[0]], nodes[rand[1]], weight='length')
route2 = nx.shortest_path(new_G, nodes[rand[1]], nodes[rand[2]], weight='length')
route3 = nx.shortest_path(new_G, nodes[rand[2]], nodes[rand[3]], weight='length')
route4 = nx.shortest_path(new_G, nodes[rand[3]], nodes[rand[4]], weight='length')
routes = [route1, route2, route3, route4]
rc = ['r', 'c', 'r', 'c']


fig, ax = ox.plot_graph_routes(new_G, routes, node_color=nc, node_size=size, route_colors=rc, route_linewidths=6, bgcolor='#FFFFFF', filepath='for_ppt.png', save=False, show=True, close=True)
# Out:
# [18 30 40 51 56]

# %%
len(nodes)
# Out:
# 60
